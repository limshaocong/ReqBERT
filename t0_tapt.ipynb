# %% [markdown]
# <a href="https://colab.research.google.com/github/limshaocong/ReqBERT/blob/main/t0_tapt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preliminaries

# %% [markdown]
# Install HuggingFace transformers and datasets libaries.

# %%
! pip install datasets transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.2.2-py3-none-any.whl (346 kB)
#      |████████████████████████████████| 346 kB 5.2 MB/s
# Collecting transformers
#   Downloading transformers-4.19.2-py3-none-any.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 46.8 MB/s
# Collecting huggingface-hub<1.0.0,>=0.1.0
#   Downloading huggingface_hub-0.7.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 4.8 MB/s
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.11.4)
# Collecting fsspec[http]>=2021.05.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 41.4 MB/s
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.64.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.6)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Collecting dill<0.3.5
#   Downloading dill-0.3.4-py2.py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 6.2 MB/s
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 60.8 MB/s
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.13)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 46.8 MB/s
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 44.0 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 50.6 MB/s
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 37.1 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (21.4.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.7 MB/s
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 49.0 MB/s
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 56.0 MB/s
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.8.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.12.2-py37-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 44.0 MB/s
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: multidict, frozenlist, yarl, urllib3, asynctest, async-timeout, aiosignal, pyyaml, fsspec, dill, aiohttp, xxhash, tokenizers, responses, multiprocess, huggingface-hub, transformers, datasets
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.5.1
#     Uninstalling dill-0.3.5.1:
#       Successfully uninstalled dill-0.3.5.1
#   Attempting uninstall: multiprocess
#     Found existing installation: multiprocess 0.70.13
#     Uninstalling multiprocess-0.70.13:
#       Successfully uninstalled multiprocess-0.70.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 asynctest-0.13.0 datasets-2.2.2 dill-0.3.4 frozenlist-1.3.0 fsspec-2022.5.0 huggingface-hub-0.7.0 multidict-6.0.2 multiprocess-0.70.12.2 pyyaml-6.0 responses-0.18.0 tokenizers-0.12.1 transformers-4.19.2 urllib3-1.25.11 xxhash-3.0.0 yarl-1.7.2

# %%
! nvidia-smi -L
# Out:
# GPU 0: Tesla P100-PCIE-16GB (UUID: GPU-2949c49b-3330-25c1-c52b-7f70815b0ae2)

# %% [markdown]
# # Import and Pre-process Data

# %%
from datasets import load_dataset

ds = load_dataset('limsc/mlm-tapt-requirements')

ds
# Out:
# Downloading:   0%|          | 0.00/805 [00:00<?, ?B/s]
# Using custom data configuration limsc--reqbert-mlm-tapt-a68ae7ead0db5cc7
# Downloading and preparing dataset csv/default (download: 4.00 MiB, generated: 7.86 MiB, post-processed: Unknown size, total: 11.86 MiB) to /root/.cache/huggingface/datasets/limsc___parquet/limsc--reqbert-mlm-tapt-a68ae7ead0db5cc7/0.0.0/0b6d5799bb726b24ad7fc7be720c170d8e497f575d02d47537de9a5bac074901...
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/214k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.98M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Dataset parquet downloaded and prepared to /root/.cache/huggingface/datasets/limsc___parquet/limsc--reqbert-mlm-tapt-a68ae7ead0db5cc7/0.0.0/0b6d5799bb726b24ad7fc7be720c170d8e497f575d02d47537de9a5bac074901. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]
# DatasetDict({
#     val: Dataset({
#         features: ['source', 'reqs'],
#         num_rows: 1990
#     })
#     train: Dataset({
#         features: ['source', 'reqs'],
#         num_rows: 37797
#     })
# })

# %%
from transformers import AutoTokenizer

# model_checkpoint = 'bert-base-cased'
model_checkpoint = 'roberta-base'
# model_checkpoint = 'allenai/scibert_scivocab_cased'

# Load pre-trained tokenizer from HuggingFace Hub
tokenizer = AutoTokenizer.from_pretrained(
    model_checkpoint,
    use_fast = True
)

# Wrapper function to batch encode dataset
def encode(requirements):
    return tokenizer(requirements['reqs'], truncation = False)

ds_tokenized = ds.map(
    encode,
    batched = True,
    remove_columns = ['source', 'reqs']
)

ds_tokenized
# Out:
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
#   0%|          | 0/2 [00:00<?, ?ba/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (592 > 512). Running this sequence through the model will result in indexing errors
#   0%|          | 0/38 [00:00<?, ?ba/s]
# DatasetDict({
#     val: Dataset({
#         features: ['input_ids', 'attention_mask'],
#         num_rows: 1990
#     })
#     train: Dataset({
#         features: ['input_ids', 'attention_mask'],
#         num_rows: 37797
#     })
# })

# %%
chunk_size = 128

def group_texts(examples):
    # Concatenate all texts
    concatenated_examples = {k: sum(examples[k], []) for k in examples.keys()}
    # Compute length of concatenated texts
    total_length = len(concatenated_examples[list(examples.keys())[0]])
    # We drop the last chunk if it's smaller than chunk_size
    total_length = (total_length // chunk_size) * chunk_size
    # Split by chunks of max_len
    result = {
        k: [t[i : i + chunk_size] for i in range(0, total_length, chunk_size)]
        for k, t in concatenated_examples.items()
    }
    # Create a new labels column
    result['labels'] = result['input_ids'].copy()
    
    return result

# %%
ds_chunked = ds_tokenized.map(group_texts, batched = True)
ds_chunked
# Out:
#   0%|          | 0/2 [00:00<?, ?ba/s]
#   0%|          | 0/38 [00:00<?, ?ba/s]
# DatasetDict({
#     val: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 650
#     })
#     train: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 12204
#     })
# })

# %%
from transformers import DataCollatorForLanguageModeling

data_collator = DataCollatorForLanguageModeling(
    tokenizer = tokenizer,
    mlm_probability = 0.15
)

# %%
batch_size = 16

batched_train_ds = ds_chunked['train'].to_tf_dataset(
    columns = ['input_ids', 'attention_mask', 'labels'],
    collate_fn = data_collator,
    shuffle = True,
    batch_size = batch_size,
)

batched_val_ds = ds_chunked['val'].to_tf_dataset(
    columns = ['input_ids', 'attention_mask', 'labels'],
    collate_fn = data_collator,
    shuffle = False,
    batch_size = batch_size,
)

# %% [markdown]
# # Task-Adpative Pre-Training (TAPT)

# %%
import tensorflow as tf
from transformers import TFAutoModelForMaskedLM, create_optimizer

tf.keras.utils.set_random_seed(1)
num_epochs = 50

def create_model():
  
  if model_checkpoint == 'allenai/scibert_scivocab_cased':
    model = TFAutoModelForMaskedLM.from_pretrained(model_checkpoint, from_pt = True)
  else:
    model = TFAutoModelForMaskedLM.from_pretrained(model_checkpoint)
  
  num_train_steps = len(batched_train_ds) * num_epochs

  optimizer, schedule = create_optimizer(
      init_lr = 2e-5,
      num_warmup_steps = 1000,
      num_train_steps = num_train_steps,
      weight_decay_rate = 0.01,
  )

  model.compile(optimizer = optimizer)

  return model

model = create_model()

model.summary()
# Out:
# Downloading:   0%|          | 0.00/627M [00:00<?, ?B/s]
# All model checkpoint layers were used when initializing TFRobertaForMaskedLM.
#
# All the layers of TFRobertaForMaskedLM were initialized from the model checkpoint at roberta-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForMaskedLM for predictions without further training.
# No loss specified in compile() - the model's internal loss computation will be used as the loss. Don't panic - this is a common way to train TensorFlow models in Transformers! To disable this behaviour, please pass a loss argument, or explicitly pass `loss=None` if you do not want your model to compute a loss.
# Model: "tf_roberta_for_masked_lm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  roberta (TFRobertaMainLayer  multiple                 124055040
#  )
#
#  lm_head (TFRobertaLMHead)   multiple                  39642969
#
# =================================================================
# Total params: 124,697,433
# Trainable params: 124,697,433
# Non-trainable params: 0
# _________________________________________________________________

# %%
import math
import os
from tensorflow.keras.callbacks import Callback, CSVLogger, ModelCheckpoint
from transformers import PushToHubCallback

class Perplexity(Callback):

    def __init__(self, validation):
        super(Perplexity, self).__init__()
        self.validation = validation

    def on_epoch_end(self, epoch, logs = {}):

        val_score = self.model.evaluate(self.validation)     
        val_perplexity = math.exp(val_score)
        logs['val_perplexity'] = val_perplexity

perplexity_cb = Perplexity(batched_val_ds)

csvlogger_f = f'{model_checkpoint}-tapt-results.csv'
csvlogger_cb = CSVLogger(csvlogger_f)

checkpoint_path = f'{model_checkpoint}' + '-cp/tapt-epoch{epoch}.ckpt'
checkpoint_dir = os.path.dirname(checkpoint_path)

# csvlogger_f = f'scibert-scivocab-tapt-results.csv'
# csvlogger_cb = CSVLogger(csvlogger_f)

# checkpoint_path = f'scibert-scivocab' + '-cp/tapt-epoch{epoch}.ckpt'
# checkpoint_dir = os.path.dirname(checkpoint_path)

modelcheckpoint_cb = ModelCheckpoint(
    filepath = checkpoint_path,
    save_weights_only = True,
    verbose = 1
)

# %%
callbacks = [perplexity_cb, csvlogger_cb, modelcheckpoint_cb]

# %%
model.fit(
    batched_train_ds,
    validation_data = batched_val_ds,
    epochs = num_epochs,
    callbacks = callbacks
)
# Out:
# Epoch 1/50
# 41/41 [==============================] - 5s 128ms/step - loss: 1.9914
#
# Epoch 1: saving model to roberta-base-cp/tapt-epoch1.ckpt
# 762/762 [==============================] - 307s 370ms/step - loss: 2.4202 - val_loss: 2.0929 - val_perplexity: 7.3261
# Epoch 2/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.8150
#
# Epoch 2: saving model to roberta-base-cp/tapt-epoch2.ckpt
# 762/762 [==============================] - 282s 370ms/step - loss: 2.0431 - val_loss: 1.8529 - val_perplexity: 6.1410
# Epoch 3/50
# 41/41 [==============================] - 5s 128ms/step - loss: 1.7378
#
# Epoch 3: saving model to roberta-base-cp/tapt-epoch3.ckpt
# 762/762 [==============================] - 278s 365ms/step - loss: 1.8965 - val_loss: 1.7499 - val_perplexity: 5.6848
# Epoch 4/50
# 41/41 [==============================] - 5s 129ms/step - loss: 1.6957
#
# Epoch 4: saving model to roberta-base-cp/tapt-epoch4.ckpt
# 762/762 [==============================] - 277s 363ms/step - loss: 1.8147 - val_loss: 1.7393 - val_perplexity: 5.4507
# Epoch 5/50
# 41/41 [==============================] - 5s 130ms/step - loss: 1.6626
#
# Epoch 5: saving model to roberta-base-cp/tapt-epoch5.ckpt
# 762/762 [==============================] - 282s 371ms/step - loss: 1.7448 - val_loss: 1.6464 - val_perplexity: 5.2729
# Epoch 6/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.6305
#
# Epoch 6: saving model to roberta-base-cp/tapt-epoch6.ckpt
# 762/762 [==============================] - 277s 364ms/step - loss: 1.6842 - val_loss: 1.5640 - val_perplexity: 5.1062
# Epoch 7/50
# 41/41 [==============================] - 5s 126ms/step - loss: 1.6072
#
# Epoch 7: saving model to roberta-base-cp/tapt-epoch7.ckpt
# 762/762 [==============================] - 281s 369ms/step - loss: 1.6539 - val_loss: 1.5980 - val_perplexity: 4.9890
# Epoch 8/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.5481
#
# Epoch 8: saving model to roberta-base-cp/tapt-epoch8.ckpt
# 762/762 [==============================] - 277s 363ms/step - loss: 1.6077 - val_loss: 1.5619 - val_perplexity: 4.7026
# Epoch 9/50
# 41/41 [==============================] - 5s 129ms/step - loss: 1.5437
#
# Epoch 9: saving model to roberta-base-cp/tapt-epoch9.ckpt
# 762/762 [==============================] - 282s 371ms/step - loss: 1.5736 - val_loss: 1.5695 - val_perplexity: 4.6819
# Epoch 10/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.5260
#
# Epoch 10: saving model to roberta-base-cp/tapt-epoch10.ckpt
# 762/762 [==============================] - 277s 363ms/step - loss: 1.5367 - val_loss: 1.5524 - val_perplexity: 4.5996
# Epoch 11/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.5254
#
# Epoch 11: saving model to roberta-base-cp/tapt-epoch11.ckpt
# 762/762 [==============================] - 277s 364ms/step - loss: 1.5053 - val_loss: 1.4983 - val_perplexity: 4.5969
# Epoch 12/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.4395
#
# Epoch 12: saving model to roberta-base-cp/tapt-epoch12.ckpt
# 762/762 [==============================] - 277s 363ms/step - loss: 1.4840 - val_loss: 1.4903 - val_perplexity: 4.2187
# Epoch 13/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.4835
#
# Epoch 13: saving model to roberta-base-cp/tapt-epoch13.ckpt
# 762/762 [==============================] - 276s 362ms/step - loss: 1.4502 - val_loss: 1.4714 - val_perplexity: 4.4083
# Epoch 14/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.4591
#
# Epoch 14: saving model to roberta-base-cp/tapt-epoch14.ckpt
# 762/762 [==============================] - 278s 364ms/step - loss: 1.4327 - val_loss: 1.4776 - val_perplexity: 4.3019
# Epoch 15/50
# 41/41 [==============================] - 5s 128ms/step - loss: 1.3980
#
# Epoch 15: saving model to roberta-base-cp/tapt-epoch15.ckpt
# 762/762 [==============================] - 277s 363ms/step - loss: 1.4158 - val_loss: 1.3959 - val_perplexity: 4.0471
# Epoch 16/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.4088
#
# Epoch 16: saving model to roberta-base-cp/tapt-epoch16.ckpt
# 762/762 [==============================] - 277s 364ms/step - loss: 1.3907 - val_loss: 1.4354 - val_perplexity: 4.0909
# Epoch 17/50
# 41/41 [==============================] - 5s 126ms/step - loss: 1.4335
#
# Epoch 17: saving model to roberta-base-cp/tapt-epoch17.ckpt
# 762/762 [==============================] - 276s 362ms/step - loss: 1.3729 - val_loss: 1.4107 - val_perplexity: 4.1934
# Epoch 18/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.4074
#
# Epoch 18: saving model to roberta-base-cp/tapt-epoch18.ckpt
# 762/762 [==============================] - 276s 363ms/step - loss: 1.3504 - val_loss: 1.4025 - val_perplexity: 4.0855
# Epoch 19/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.4059
#
# Epoch 19: saving model to roberta-base-cp/tapt-epoch19.ckpt
# 762/762 [==============================] - 276s 363ms/step - loss: 1.3360 - val_loss: 1.3971 - val_perplexity: 4.0792
# Epoch 20/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.3942
#
# Epoch 20: saving model to roberta-base-cp/tapt-epoch20.ckpt
# 762/762 [==============================] - 276s 362ms/step - loss: 1.3292 - val_loss: 1.3959 - val_perplexity: 4.0317
# Epoch 21/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.4220
#
# Epoch 21: saving model to roberta-base-cp/tapt-epoch21.ckpt
# 762/762 [==============================] - 277s 363ms/step - loss: 1.3122 - val_loss: 1.3732 - val_perplexity: 4.1452
# Epoch 22/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.3532
#
# Epoch 22: saving model to roberta-base-cp/tapt-epoch22.ckpt
# 762/762 [==============================] - 276s 363ms/step - loss: 1.2911 - val_loss: 1.3865 - val_perplexity: 3.8700
# Epoch 23/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.3638
#
# Epoch 23: saving model to roberta-base-cp/tapt-epoch23.ckpt
# 762/762 [==============================] - 277s 364ms/step - loss: 1.2799 - val_loss: 1.4103 - val_perplexity: 3.9110
# Epoch 24/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.3377
#
# Epoch 24: saving model to roberta-base-cp/tapt-epoch24.ckpt
# 762/762 [==============================] - 276s 363ms/step - loss: 1.2723 - val_loss: 1.3576 - val_perplexity: 3.8104
# Epoch 25/50
# 41/41 [==============================] - 5s 129ms/step - loss: 1.3349
#
# Epoch 25: saving model to roberta-base-cp/tapt-epoch25.ckpt
# 762/762 [==============================] - 277s 364ms/step - loss: 1.2611 - val_loss: 1.3646 - val_perplexity: 3.7997
# Epoch 26/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.3242
#
# Epoch 26: saving model to roberta-base-cp/tapt-epoch26.ckpt
# 762/762 [==============================] - 276s 363ms/step - loss: 1.2523 - val_loss: 1.3297 - val_perplexity: 3.7590
# Epoch 27/50
# 41/41 [==============================] - 5s 128ms/step - loss: 1.3278
#
# Epoch 27: saving model to roberta-base-cp/tapt-epoch27.ckpt
# 762/762 [==============================] - 276s 362ms/step - loss: 1.2365 - val_loss: 1.3550 - val_perplexity: 3.7728
# Epoch 28/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.3444
#
# Epoch 28: saving model to roberta-base-cp/tapt-epoch28.ckpt
# 762/762 [==============================] - 281s 369ms/step - loss: 1.2318 - val_loss: 1.3432 - val_perplexity: 3.8359
# Epoch 29/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.3183
#
# Epoch 29: saving model to roberta-base-cp/tapt-epoch29.ckpt
# 762/762 [==============================] - 277s 363ms/step - loss: 1.2249 - val_loss: 1.3244 - val_perplexity: 3.7372
# Epoch 30/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.3387
#
# Epoch 30: saving model to roberta-base-cp/tapt-epoch30.ckpt
# 762/762 [==============================] - 277s 363ms/step - loss: 1.2072 - val_loss: 1.3330 - val_perplexity: 3.8140
# Epoch 31/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.3039
#
# Epoch 31: saving model to roberta-base-cp/tapt-epoch31.ckpt
# 762/762 [==============================] - 277s 364ms/step - loss: 1.1986 - val_loss: 1.3352 - val_perplexity: 3.6835
# Epoch 32/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.3320
#
# Epoch 32: saving model to roberta-base-cp/tapt-epoch32.ckpt
# 762/762 [==============================] - 277s 363ms/step - loss: 1.1803 - val_loss: 1.2937 - val_perplexity: 3.7887
# Epoch 33/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.3146
#
# Epoch 33: saving model to roberta-base-cp/tapt-epoch33.ckpt
# 762/762 [==============================] - 278s 365ms/step - loss: 1.1813 - val_loss: 1.2694 - val_perplexity: 3.7233
# Epoch 34/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.3029
#
# Epoch 34: saving model to roberta-base-cp/tapt-epoch34.ckpt
# 762/762 [==============================] - 277s 363ms/step - loss: 1.1731 - val_loss: 1.3122 - val_perplexity: 3.6800
# Epoch 35/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.2945
#
# Epoch 35: saving model to roberta-base-cp/tapt-epoch35.ckpt
# 762/762 [==============================] - 277s 363ms/step - loss: 1.1650 - val_loss: 1.3023 - val_perplexity: 3.6492
# Epoch 36/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.3248
#
# Epoch 36: saving model to roberta-base-cp/tapt-epoch36.ckpt
# 762/762 [==============================] - 277s 364ms/step - loss: 1.1510 - val_loss: 1.3256 - val_perplexity: 3.7616
# Epoch 37/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.2597
#
# Epoch 37: saving model to roberta-base-cp/tapt-epoch37.ckpt
# 762/762 [==============================] - 276s 363ms/step - loss: 1.1487 - val_loss: 1.3326 - val_perplexity: 3.5244
# Epoch 38/50
# 41/41 [==============================] - 5s 128ms/step - loss: 1.3073
#
# Epoch 38: saving model to roberta-base-cp/tapt-epoch38.ckpt
# 762/762 [==============================] - 281s 369ms/step - loss: 1.1351 - val_loss: 1.3253 - val_perplexity: 3.6962
# Epoch 39/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.2976
#
# Epoch 39: saving model to roberta-base-cp/tapt-epoch39.ckpt
# 762/762 [==============================] - 277s 363ms/step - loss: 1.1341 - val_loss: 1.2779 - val_perplexity: 3.6605
# Epoch 40/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.3383
#
# Epoch 40: saving model to roberta-base-cp/tapt-epoch40.ckpt
# 762/762 [==============================] - 278s 364ms/step - loss: 1.1291 - val_loss: 1.2636 - val_perplexity: 3.8124
# Epoch 41/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.3432
#
# Epoch 41: saving model to roberta-base-cp/tapt-epoch41.ckpt
# 762/762 [==============================] - 278s 364ms/step - loss: 1.1263 - val_loss: 1.2740 - val_perplexity: 3.8315
# Epoch 42/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.2800
#
# Epoch 42: saving model to roberta-base-cp/tapt-epoch42.ckpt
# 762/762 [==============================] - 277s 363ms/step - loss: 1.1293 - val_loss: 1.3055 - val_perplexity: 3.5966
# Epoch 43/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.2490
#
# Epoch 43: saving model to roberta-base-cp/tapt-epoch43.ckpt
# 762/762 [==============================] - 282s 371ms/step - loss: 1.1131 - val_loss: 1.2650 - val_perplexity: 3.4867
# Epoch 44/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.2849
#
# Epoch 44: saving model to roberta-base-cp/tapt-epoch44.ckpt
# 762/762 [==============================] - 283s 371ms/step - loss: 1.1135 - val_loss: 1.3089 - val_perplexity: 3.6142
# Epoch 45/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.2712
#
# Epoch 45: saving model to roberta-base-cp/tapt-epoch45.ckpt
# 762/762 [==============================] - 283s 371ms/step - loss: 1.1060 - val_loss: 1.2322 - val_perplexity: 3.5652
# Epoch 46/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.2920
#
# Epoch 46: saving model to roberta-base-cp/tapt-epoch46.ckpt
# 762/762 [==============================] - 277s 363ms/step - loss: 1.1110 - val_loss: 1.2760 - val_perplexity: 3.6400
# Epoch 47/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.2903
#
# Epoch 47: saving model to roberta-base-cp/tapt-epoch47.ckpt
# 762/762 [==============================] - 277s 363ms/step - loss: 1.1042 - val_loss: 1.3129 - val_perplexity: 3.6338
# Epoch 48/50
# 41/41 [==============================] - 5s 128ms/step - loss: 1.2957
#
# Epoch 48: saving model to roberta-base-cp/tapt-epoch48.ckpt
# 762/762 [==============================] - 278s 364ms/step - loss: 1.1100 - val_loss: 1.2923 - val_perplexity: 3.6537
# Epoch 49/50
# 41/41 [==============================] - 5s 128ms/step - loss: 1.2653
#
# Epoch 49: saving model to roberta-base-cp/tapt-epoch49.ckpt
# 762/762 [==============================] - 277s 363ms/step - loss: 1.0956 - val_loss: 1.2815 - val_perplexity: 3.5442
# Epoch 50/50
# 41/41 [==============================] - 5s 127ms/step - loss: 1.2969
#
# Epoch 50: saving model to roberta-base-cp/tapt-epoch50.ckpt
# 762/762 [==============================] - 277s 363ms/step - loss: 1.1009 - val_loss: 1.2797 - val_perplexity: 3.6578

# %% [markdown]
# # Save Model to HuggingFace Hub

# %%
! huggingface-cli login
# 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
# Out:
#         _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#         _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#         _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#         _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#         _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#         To login, `huggingface_hub` now requires a token generated from https://huggingface.co/settings/tokens .
#         (Deprecated, will be removed in v0.3.0) To login with username and password instead, interrupt with Ctrl+C.
#
# Token:
# Login successful
# Your token has been saved to /root/.huggingface/token
# Authenticated through git-credential store but this isn't the helper defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub. Run the following command in your terminal in case you want to set this credential helper as the default
#
# git config --global credential.helper store

# %%
os.listdir(checkpoint_dir)

chosen_epoch = 50
chosen_epoch_path = f'{model_checkpoint}-cp/tapt-epoch{chosen_epoch}.ckpt'

# Reinstate checkpoint weights
model = create_model()
model.load_weights(chosen_epoch_path)
# Out:
# All model checkpoint layers were used when initializing TFRobertaForMaskedLM.
#
# All the layers of TFRobertaForMaskedLM were initialized from the model checkpoint at roberta-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForMaskedLM for predictions without further training.
# No loss specified in compile() - the model's internal loss computation will be used as the loss. Don't panic - this is a common way to train TensorFlow models in Transformers! To disable this behaviour, please pass a loss argument, or explicitly pass `loss=None` if you do not want your model to compute a loss.

# %%
repo_dict = {
  'bert-base-cased' : 'limsc/reqbert-tapt',
  'roberta-base' : 'limsc/reqroberta-tapt',
  'allenai/scibert_scivocab_cased' : 'limsc/reqscibert-tapt'
}

repo_path = repo_dict[model_checkpoint] + f'-epoch{chosen_epoch}'

model.push_to_hub(repo_path)
# Out:
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/utils/_deprecation.py:43: FutureWarning: Pass token='reqroberta-tapt-epoch50' as keyword args. From version 0.8 passing these as positional arguments will result in an error
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/hf_api.py:676: FutureWarning: `create_repo` now takes `token` as an optional positional argument. Be sure to adapt your code!
#   FutureWarning,
# Cloning https://huggingface.co/limsc/reqroberta-tapt-epoch50 into local empty directory.
# Upload file tf_model.h5:   0%|          | 3.34k/625M [00:00<?, ?B/s]
# remote: Enforcing permissions...
# remote: Allowed refs: all
# To https://huggingface.co/limsc/reqroberta-tapt-epoch50
#    05e9b0f..7614741  main -> main
# 'https://huggingface.co/limsc/reqroberta-tapt-epoch50/commit/7614741d0cedc6d8170e62d9925604140a0de8ff'
